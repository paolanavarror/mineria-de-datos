# %% [markdown]
# <a href="https://colab.research.google.com/github/paolanavarror/mineria-de-datos/blob/main/MineriaDeDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mineria de Datos

# %% [markdown]
# ## Primer Parcial

# %% [markdown]
# ### Introducción

# %% [markdown]
# #### Conceptos

# %% [markdown]
# ##### Minería de Datos:
# Es una técnica asistida por computadora que se utiliza en los análisis para procesar y explorar grandes conjuntos de datos.
# ##### Ciencia de datos:
# Es el estudio de datos con el fin de extraer información significativa para empresas. Es un enfoque multidisciplinario que combina principios y prácticas del campo de las matemáticas, la estadística, la inteligencia artificial y la ingeniería de computación para analizar grandes cantidades de datos.

# %% [markdown]
# ##### Comandos

# %% [markdown]
# Help and Documentation in IPython

# %%
help()
# Out:
# Welcome to Python 3.12's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.12/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q" or "quit".
#
#
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
len?

# %%
L = [1,2,3]
L.insert?

# %%
L?

# %%
def square(a):
# Out:
#   File "/tmp/ipython-input-3003008882.py", line 1
#     def square(a):
#                   ^
# SyntaxError: incomplete input

# %%
square?
# Out:
# Object `square` not found.

# %%
square??
# Out:
# Object `square` not found.

# %%
len??

# %%
L.<TAB>
# Out:
#   File "/tmp/ipython-input-3745167853.py", line 1
#     L.<TAB>
#       ^
# SyntaxError: invalid syntax

# %%
L.c<TAB>
# Out:
#   File "/tmp/ipython-input-379562613.py", line 1
#     L.c<TAB>
#             ^
# SyntaxError: invalid syntax

# %%
L.cou<TAB>
# Out:
#   File "/tmp/ipython-input-2971403979.py", line 1
#     L.cou<TAB>
#               ^
# SyntaxError: invalid syntax

# %%
L._<TAB>
# Out:
#   File "/tmp/ipython-input-3055270103.py", line 1
#     L._<TAB>
#             ^
# SyntaxError: invalid syntax

# %%
from itertools import co<TAB>
# Out:
#   File "/tmp/ipython-input-461150734.py", line 1
#     from itertools import co<TAB>
#                             ^
# SyntaxError: invalid syntax

# %%
import <TAB>
# Out:
#   File "/tmp/ipython-input-709411292.py", line 1
#     import <TAB>
#            ^
# SyntaxError: invalid syntax

# %%
*Warning?

# %%
str.*find*?

# %% [markdown]
# **IPython Magic Commands**

# %%
def donothing(x):
  return x

# %%
# El comando sirve para evaluar el desempeño en térmios de tiempo
# %timeit L = [n ** 2 for n in range(1000)]
# Out:
# 72.2 µs ± 697 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# El comando %%timeit sirve para evaluar el desempeño solo que este abarca varias lineas de código en lugar de una
# %%timeit
L = []
for n in range(1000):
    L.append(n ** 2)
# Out:
# 87.6 µs ± 15.5 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit?

# %%
# %%timeit?

# %% [markdown]
# **IPython and Shell Commands**

# %%
# !ls
# Out:
# sample_data

# %%
# %cd sample_data/
# Out:
# /content/sample_data

# %%
# %ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
# !cat README.md
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://docs.google.com/document/d/e/2PACX-1vRhYtsvc5eOR2FWNCwaBiKL6suIOrxJig8LcSBbmCbyYsayia_DvPOOBlXZ4CAlQ5nlDD8kTaIDRwrN/pub
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).

# %%
#Cuando tenermo svariables de ambiente podemso mofiicar variables y cambiar el comportomaiento
# Sirve para ver las variables de entorno
# %env
# Out:
# {'SHELL': '/bin/bash',
#  'COLAB_JUPYTER_TRANSPORT': 'ipc',
#  'CGROUP_MEMORY_EVENTS': '/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events',
#  'VM_GCE_METADATA_HOST': '169.254.169.253',
#  'MODEL_PROXY_HOST': 'https://mp.kaggle.net',
#  'HOSTNAME': 'b506c8c217e8',
#  'LANGUAGE': 'en_US',
#  'TBE_RUNTIME_ADDR': '172.28.0.1:8011',
#  'GCE_METADATA_TIMEOUT': '3',
#  'COLAB_JUPYTER_IP': '172.28.0.12',
#  'COLAB_LANGUAGE_SERVER_PROXY_ROOT_URL': 'http://172.28.0.1:8013/',
#  'KMP_LISTEN_PORT': '6000',
#  'TF_FORCE_GPU_ALLOW_GROWTH': 'true',
#  'ENV': '/root/.bashrc',
#  'PWD': '/',
#  'TBE_EPHEM_CREDS_ADDR': '172.28.0.1:8009',
#  'COLAB_LANGUAGE_SERVER_PROXY_REQUEST_TIMEOUT': '30s',
#  'TBE_CREDS_ADDR': '172.28.0.1:8008',
#  'COLAB_JUPYTER_TOKEN': '<hidden>',
#  'LAST_FORCED_REBUILD': '20250623',
#  'TCLLIBPATH': '/usr/share/tcltk/tcllib1.20',
#  'COLAB_KERNEL_MANAGER_PROXY_HOST': '172.28.0.12',
#  'UV_BUILD_CONSTRAINT': '',
#  'COLAB_WARMUP_DEFAULTS': '1',
# ...

# %% [markdown]
# **Understanding Data Types in Python**

# %% [markdown]
# c es un lenguaje altamente tipado, una vez que declaramos una variable se queda con el mismo tipo.
# Pyhton es un lenguaje de tipado dinamico.

# %% [markdown]
# Una estructura dentro de esa estructutara esst el tipo, el tamaño, etc
# Tipo de objeto: modifica el tipo del variable que estamos utilizando
# Una lisa en Py es una secuencia de, podemos tener

# %%
  #Cusndo importamos un paquet en Py utilizamos np
  import numpy as np

# %%
np.array([1, 4, 2, 5, 3])
# Out:
# array([1, 4, 2, 5, 3])

# %%
np.array([3.14, 4, 2, 3])
# Out:
# array([3.14, 4.  , 2.  , 3.  ])

# %%
#Es un tipo de float, de que tan preciso
np.array([1, 2, 3, 4], dtype='float32')
# Out:
# array([1., 2., 3., 4.], dtype=float32)

# %%
np.array([1, 2, 3, 4], dtype='int')
# Out:
# array([1, 2, 3, 4])

# %%
#Listas de contencipon, arreglos bideminionales, cliclos anidados
#Ejecuta este de ranfo tmoando el primero de la lista, en Py un rango genera una secuencia, con el
# Empieza en 2 y termina antes del 5
#Luego toma el rango del 6 y lo
np.array([range(i, i + 3) for i in [2, 4, 6]])
